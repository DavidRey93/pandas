# %%
import pandas as pd

# %%
data = {"name":["ana","pol","juan"],
        "age":[20,30,40,],
        "RH":["A+","B+","O+"]}

# %%
pd.DataFrame(data)
# Out:
#    name  age  RH
# 0   ana   20  A+
# 1   pol   30  B+
# 2  juan   40  O+

# %%
lista1=[["david",30,"A+"],
        ["pedro",35,"B-"],
        ["diana",40,"A+"]]

# %%
pd.DataFrame(lista1)
# Out:
#        0   1   2
# 0  david  30  A+
# 1  pedro  35  B-
# 2  diana  40  A+

# %%
lista = pd.DataFrame(lista1, columns=["name","age","RH"])
lista
# Out:
#     name  age  RH
# 0  david   30  A+
# 1  pedro   35  B-
# 2  diana   40  A+

# %%
file= "LargestCompaniesInUSAbyReveneue.csv"
df = pd.read_csv(file)
df
# Out:
#     Rank                 Name                    Industry  \
# 0      1              Walmart       General merchandisers
# 1      2               Amazon  Retail and Cloud Computing
# 2      3                Apple        Electronics industry
# 3      4           CVS Health                  Healthcare
# 4      5   UnitedHealth Group                  Healthcare
# ..   ...                  ...                         ...
# 95    96     General Dynamics        Airspace and defense
# 96    97                  CHS     Agriculture cooperative
# 97    98                 USAA                  Financials
# 98    99  Northwestern Mutual                   Insurance
# 99   100                Nucor                      Metals
#
#    Revenue (USD millions) Revenue growth  Employees  \
# 0                 572,754           2.4%  2,300,000
# 1                 469,822          21.7%  1,608,000
# 2                 365,817          33.2%    154,000
# 3                 292,111          32.0%    258,000
# ...

# %%
df.head(10)
# Out:
#    Rank                  Name                    Industry  \
# 0     1               Walmart       General merchandisers
# 1     2                Amazon  Retail and Cloud Computing
# 2     3                 Apple        Electronics industry
# 3     4            CVS Health                  Healthcare
# 4     5    UnitedHealth Group                  Healthcare
# 5     6           Exxon Mobil          Petroleum industry
# 6     7    Berkshire Hathaway                Conglomerate
# 7     8              Alphabet                  Technology
# 8     9  McKesson Corporation                      Health
# 9    10     AmerisourceBergen     Pharmaceutical industry
#
#   Revenue (USD millions) Revenue growth  Employees                Headquarters
# 0                572,754           2.4%  2,300,000       Bentonville, Arkansas
# 1                469,822          21.7%  1,608,000         Seattle, Washington
# 2                365,817          33.2%    154,000       Cupertino, California
# ...

# %%
df.tail(10)
# Out:
#     Rank                      Name                 Industry  \
# 90    91       Enterprise Products       Petroleum industry
# 91    92                      TIAA                Insurance
# 92    93        Oracle Corporation                 Software
# 93    94  Thermo Fisher Scientific   Laboratory instruments
# 94    95         Coca-Cola Company                Beverages
# 95    96          General Dynamics     Airspace and defense
# 96    97                       CHS  Agriculture cooperative
# 97    98                      USAA               Financials
# 98    99       Northwestern Mutual                Insurance
# 99   100                     Nucor                   Metals
#
#    Revenue (USD millions) Revenue growth Employees  \
# 90                 40,807          50.0%     6,911
# 91                 40,526           2.6%    15,065
# 92                 40,479           3.6%   132,000
# 93                 39,211          21.7%   129,000
# ...

# %%
df[["Industry"]]
# Out:
#                       Industry
# 0        General merchandisers
# 1   Retail and Cloud Computing
# 2         Electronics industry
# 3                   Healthcare
# 4                   Healthcare
# ..                         ...
# 95        Airspace and defense
# 96     Agriculture cooperative
# 97                  Financials
# 98                   Insurance
# 99                      Metals
#
# [100 rows x 1 columns]

# %%
df.loc[:,["Name","Industry","Revenue growth"]]
# Out:
#                    Name                    Industry Revenue growth
# 0               Walmart       General merchandisers           2.4%
# 1                Amazon  Retail and Cloud Computing          21.7%
# 2                 Apple        Electronics industry          33.2%
# 3            CVS Health                  Healthcare          32.0%
# 4    UnitedHealth Group                  Healthcare          11.8%
# ..                  ...                         ...            ...
# 95     General Dynamics        Airspace and defense           8.7%
# 96                  CHS     Agriculture cooperative           1.4%
# 97                 USAA                  Financials           3.2%
# 98  Northwestern Mutual                   Insurance           8.8%
# 99                Nucor                      Metals          81.2%
#
# [100 rows x 3 columns]

# %%
df[["Revenue growth"]]
# Out:
#    Revenue growth
# 0            2.4%
# 1           21.7%
# 2           33.2%
# 3           32.0%
# 4           11.8%
# ..            ...
# 95           8.7%
# 96           1.4%
# 97           3.2%
# 98           8.8%
# 99          81.2%
#
# [100 rows x 1 columns]

# %%
df.loc[85:,["Name","Employees"]]
# Out:
#                             Name Employees
# 85                    John Deere    75,550
# 86              American Express    64,000
# 87           Abbott Laboratories   113,000
# 88                  StoneX Group     3,242
# 89  Plains All American Pipeline     4,100
# 90           Enterprise Products     6,911
# 91                          TIAA    15,065
# 92            Oracle Corporation   132,000
# 93      Thermo Fisher Scientific   129,000
# 94             Coca-Cola Company    79,000
# 95              General Dynamics   103,100
# 96                           CHS     9,941
# 97                          USAA    37,335
# 98           Northwestern Mutual     7,585
# 99                         Nucor    28,800
